# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tqdm 
import matplotlib.pyplot as plt
import math
import scipy

# %%
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-f33cf0cb8fd3> in <module>
# ----> 1 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'bs4'

# %%
import xgboost as xgb
import lightgbm as lgb
import catboost as cat

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder,OrdinalEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.calibration import calibration_curve, CalibratedClassifierCV

# %%
from sklearn.metrics import roc_auc_score, roc_curve,confusion_matrix

# %% [markdown]
# # Loading Raw Data

# %%
raw_data = pd.read_csv('telecomChurn.zip')

# %%
colDescribe = '''<div class="sc-kgMgwB klFtMq"><div class="sc-fYIOIr djQgRq"><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">rev_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean monthly revenue (charge amount)</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mou_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of monthly minutes of use</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">totmrc_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean total monthly recurring charge</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">da_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of directory assisted calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">ovrmou_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean overage minutes of use</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">ovrrev_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean overage revenue</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">vceovr_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean revenue of voice overage </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">datovr_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Mean revenue of data overage</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">roam_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of roaming calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">change_mou</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Percentage change in monthly minutes of use vs previous three month average</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">change_rev</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Percentage change in monthly revenue vs previous three month average</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">drop_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Mean number of dropped (failed) voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">drop_dat_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of dropped (failed) data calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">blck_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of blocked (failed) voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">blck_dat_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of blocked (failed) data calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">unan_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of unanswered voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">unan_dat_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of unanswered data calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">plcd_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of attempted voice calls placed</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">plcd_dat_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of attempted data calls placed</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">recv_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of received voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">recv_sms_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> N</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">comp_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of completed voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">comp_dat_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of completed data calls </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">custcare_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of customer care calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">ccrndmou_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean rounded minutes of use of customer care calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">cc_mou_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of customer care (see CUSTCARE_MEAN) calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">inonemin_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of inbound calls less than one minute</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">threeway_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of three way calls </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mou_cvce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of completed voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mou_cdat_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of completed data calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mou_rvce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of received voice calls </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">owylis_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of outbound wireless to wireless voice calls </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mouowylisv_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of outbound wireless to wireless voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">iwylis_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> N</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mouiwylisv_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of inbound wireless to wireless voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">peak_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of inbound and outbound peak voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">peak_dat_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of peak data calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mou_peav_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of peak voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mou_pead_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of peak data calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">opk_vce_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of off-peak voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">opk_dat_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of off-peak data calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mou_opkv_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of off-peak voice calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mou_opkd_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean unrounded minutes of use of off-peak data calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">drop_blk_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of dropped or blocked calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">attempt_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of attempted calls </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">complete_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of completed calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">callfwdv_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Mean number of call forwarding calls </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">callwait_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of call waiting calls</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">churn</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Instance of churn between 31-60 days after observation date</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">months</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Total number of months in service</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">uniqsubs</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Number of unique subscribers in the household</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">actvsubs</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Number of active subscribers in household</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">new_cell</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">New cell phone user</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">crclscod</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Credit class code</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">check</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">asl_flag</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Account spending limit</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">totcalls</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Total number of calls over the life of the customer</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">totmou</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Total minutes of use over the life of the customer</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">totrev</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Total revenue</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">adjrev</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Billing adjusted total revenue over the life of the customer</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">adjmou</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Billing adjusted total minutes of use over the life of the customer</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">adjqty</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Billing adjusted total number of calls over the life of the customer </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">avgrev</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Average monthly revenue over the life of the customer</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">avgmou</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Average monthly minutes of use over the life of the customer</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">avgqty</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Average monthly number of calls over the life of the customer</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">avg3mou</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Average monthly minutes of use over the previous three months</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">avg3qty</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Average monthly number of calls over the previous three months </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">avg3rev</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Average monthly revenue over the previous three months</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">avg6mou</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Average monthly minutes of use over the previous six months</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">avg6qty</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Average monthly number of calls over the previous six months</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">avg6rev</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Average monthly revenue over the previous six months </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">prizm_social_one</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Social group letter only</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">area</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Geogrpahic area </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">dualband</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Dualband</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">refurb_new</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Handset: refurbished or new</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">hnd_price</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Current handset price</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">phones</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Number of handsets issued</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">models</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Number of models issued</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">hnd_webcap</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Handset web capability</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">truck</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Truck indicator </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">rv</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">RV indicator</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">ownrent</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Home owner/renter status</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">lor</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Length of residence</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">dwlltype</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ"> Dwelling Unit type</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">marital</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Marital Status </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">adults</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Number of adults in household</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">infobase</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">InfoBase match</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">income</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Estimated income</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">numbcars</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Known number of vehicles</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">HHstatin</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Premier household status indicator</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">dwllsize</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Dwelling size </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">forgntvl</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Foreign travel dummy variable</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">ethnic</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Ethnicity roll-up code</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">kid0_2</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Child 0 - 2 years of age in household</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">kid3_5</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Child 3 - 5 years of age in household </p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">kid6_10</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Child 6 - 10 years of age in household</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">kid11_15</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Child 11 - 15 years of age in household</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">text_format</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">kid16_17</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Child 16 - 17 years of age in household</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">check</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">creditcd</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Credit card indicator</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">eqpdays</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Number of days (age) of current equipment</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">vpn_key</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">Customer_ID</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">N</p></div></div></div>
'''

# %%
colDescribe
# Out:
# '<div class="sc-kgMgwB klFtMq"><div class="sc-fYIOIr djQgRq"><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">rev_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean monthly revenue (charge amount)</p></div><div class="sc-hrzOVh sc-hhVlin hHuaEt gqzgEC"><div class="sc-gTeHfO hnlNZT"><i sizevalue="12px" class="rmwc-icon google-material-icons sc-gKXOVf jWAECi">grid_3x3</i><span class="sc-bZnhIo sc-iTONeN sc-dyoGmK dPnCzY jTNbzy gUlzIG">mou_Mean</span><i color="#5F6368" sizevalue="18px" class="rmwc-icon google-material-icons sc-gKXOVf kqAZRH">sort</i></div><p class="sc-iIPllB sc-gicCDI sc-bXVllQ fFJlHp dDCeGO fUzuIJ">Mean number of monthly minutes of use</p></div><div class="sc
# ...
